# %%
#| default_exp chatbot

# %%
import sys
import os

# Add the parent directory to sys.path
sys.path.append(os.path.abspath(".."))

from jupyter_mentor.llm import LLM, FileModel

# %%
#| export
import ipywidgets as widgets
import traitlets
from ipywidgets import Textarea, Text, Layout, HBox, Stack, Layout
from traitlets import HasTraits
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)

from jupyter_mentor.llm import FileModel

# %%
class ChatBotModel(FileModel):

    bot_identity = traitlets.Unicode()
    human_identity = traitlets.Unicode()

    def __init__(self, bot_template="", human_template="{input_text}"):
        super().__init__()
        self.bot_identity = "You are playing the role of a tutor/educator"
        self.human_identity = "I am a student"
        self.update_bot_template(bot_template)
        self.update_human_template(human_template)

    def update_bot_template(self, bot_template):
        self.bot_message_prompt = SystemMessagePromptTemplate.from_template("\n\n".join([self.bot_identity, bot_template]))

    def update_human_template(self, human_template):
        self.human_message_prompt = HumanMessagePromptTemplate.from_template("\n\n".join([self.human_identity, human_template]))

    def prompt(self, input_text):
        ret = self.llm.invoke(input_text)
        return ret.content
    
    def prompt_with_template(self, kwargs):
        self.chat_prompt = ChatPromptTemplate.from_messages([self.bot_message_prompt, self.human_message_prompt])   
        ret = self.llm.invoke(self.chat_prompt.format_prompt(**kwargs))
        return ret.content

    def prompt_course_files(self, input_text):
        if self.db:
            try:
                docs = self.db.similarity_search(input_text, k=1)
                docs_content = " ".join([d.page_content for d in docs])
                self.update_bot_template(self.bot_identity + "\n\nAnswer the question based on the following information: {docs}\n\n{input_text}")
                self.chat_prompt = ChatPromptTemplate.from_messages([self.bot_message_prompt, self.human_message_prompt])   
                ret = self.llm.invoke(self.chat_prompt.format_prompt(docs=docs, input_text=input_text)) 
                return "\n\n".join([ret.content + '\n\nSourced from ' + docs[0].metadata['source'] + ': \n', docs_content])
            except Exception as e: 
                return e
        else:
            return self.prompt(input_text)

# %%
chatbot_model = ChatBotModel()
#chatbot_model.prompt('hello')
#chatbot_model.prompt_with_template({'input_text': 'hi'})

# %%
chatbot_model.load_pdf_to_db("course_files/STP 420 spring 2024 course syllabus.pdf")

# %%
chatbot_model.prompt_course_files("when will we learn about integration?", )
# Out:
# 'This syllabus is for STP 420: Introduction to Applied Statistics, not a calculus-based course like MAT 117: College Algebra, which might cover integration.  Therefore, the provided document does not contain information about when you will learn about integration.  To find out when you will learn about integration, you should consult the syllabus for your calculus course.\n\nSourced from course_files/STP 420 spring 2024 course syllabus.pdf: \n\n\nSPRING 2024 STP 420 \n Arizona State University, School of Mathematical and Statistical Sciences 1 \nSTP 420: Introduction to Applied Statistics-Spring 2024 \n \nInstructor: Raymond Ye Zhang Office number: ECA 215 \nEmail: yzhan633@asu.edu \nOffice Hours: Monday, Wednesday, Friday 12 pm to 1 \npm Tuesday, Thursday 1:30 pm to 2:30 pm in ECA 215 and \nvia zoom https://asu.zoom.us/j/8502350321 \n \nPhone: (480) 465-7602      \n \nTopic Calendar \n \n \n \nNo. Week Sections Covered (Tentative)  Comments \n1 Jan. 8 – Jan. 12 Introductions, 1.1: Categorical and quantitative variables 1.2: \nGraphical displays of distribution \n \n2 Jan. 15 – Jan. 19 \n1.3: Numerical summary of distribution including center and \nspread     \n \nMonday, January 15 \nis MLK Day \n3 Jan. 22 – Jan. 26 1.4: Density curve and normal distribution                   \n  \n4 Jan. 29– Feb. 2 4.2: Probability model including sample space and events  \n4.5: General probability rules  \n5 Feb. 5– Feb. 9 \n4.3: Discrete and continuous random variables \n4.4: Find expected value and variance of a random variable \n \n \n6 Feb. 12– Feb. 16 \n5.1: Sampling distribution of sample mean \n5.2: Sampling distribution of sample proportion \nTEST #1 (chapters 1, 4) \n \n7 Feb. 19 – Feb. 23 6.1: Confidence interval  \n  \n8 Feb. 26 – Mar. 1  6.2: Hypothesis test  \n \n \n9 Mar. 4 – Mar. 8  Spring Break \n10 Mar. 11 – Mar. 15 6.4: Type I and Type II errors, power of a test  \n7.1: Confidence interval and hypothesis test using t distribution  \n11 Mar. 18 – Mar. 22 \n7.2: Confidence interval and hypothesis test for two population \nmeans \nTEST #2 (chapters 5, 6, section 7.1) \n \n12 Mar. 25 – Mar. 29 12.1: One way ANOV A test           \n \nCourse withdrawal \nDeadline (March \n31) \n13 Apr. 1– Apr. 5 \n8.1: Confidence interval and hypothesis test for one population \nproportion \n9.1: Two-way table and introduction to Chi-square test'

# %%
class ChatBotView(widgets.VBox):
    
    def __init__(self):
        # If you forget to call the superconstructor on an extended widget
        # you will get an AttributeError: object has no attribute '_model_id'
        super().__init__()

        self.chat = Textarea(
            disabled = True,
            layout=Layout(width='90%', height='400px')
        )
        self.user_input_and_submit = HBox()
        self.user_input = widgets.Text(
            placeholder='Message AI chatbot...',
            #layout=Layout(width='100%')
        )
        self.submit_button = widgets.Button(
            value=False,
            disabled=False,
            button_style='success',
            icon='arrow-circle-right' 
        )
        self.user_input_and_submit.children = (self.user_input, self.submit_button)

        self.children = (self.chat, self.user_input_and_submit)

# %%
chatbot_view = ChatBotView()
chatbot_view
# Out:
# ChatBotView(children=(Textarea(value='', disabled=True, layout=Layout(height='400px', width='90%')), HBox(chil…

# %%
class ChatBot(ChatBotView):

    def __init__(self, model):
        # If you forget to call the superconstructor on an extended widget
        # you will get an AttributeError: object has no attribute '_model_id'
        super().__init__()
        self.submit_button.on_click(self.on_click)
        self.model =model

    def on_click(self, change):
        self.chat.value = self.chat.value + "USER: " + self.user_input.value + '\n\n'
        self.user_input.value = ''
        ret = self.model.prompt_course_files(self.user_input.value)
        self.chat.value = self.chat.value +  "CHATBOT: "  + ret + '\n\n'

# %%
chatbot = ChatBot(chatbot_model)
chatbot
# Out:
# ChatBot(children=(Textarea(value='', disabled=True, layout=Layout(height='400px', width='90%')), HBox(children…

# %%
file_model = FileModel()
file_model.load_pdf_to_db("course_files/STP 420 spring 2024 course syllabus.pdf") #file as input

# %%
#|hide
import nbdev; nbdev.nbdev_export()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #|hide
# ----> 2 import nbdev; nbdev.nbdev_export()
#
# File c:\Users\jahnv\OneDrive\Desktop\Jahnvi\ASU\researchProject\jupyter-mentor\venv\Lib\site-packages\fastcore\script.py:116, in call_parse.<locals>._f(*args, **kwargs)
#     113 @wraps(func)
#     114 def _f(*args, **kwargs):
#     115     mod = inspect.getmodule(inspect.currentframe().f_back)
# --> 116     if not mod: return func(*args, **kwargs)
#     117     if not SCRIPT_INFO.func and mod.__name__=="__main__": SCRIPT_INFO.func = func.__name__
#     118     if len(sys.argv)>1 and sys.argv[1]=='': sys.argv.pop(1)
#
# File c:\Users\jahnv\OneDrive\Desktop\Jahnvi\ASU\researchProject\jupyter-mentor\venv\Lib\site-packages\nbdev\doclinks.py:150, in nbdev_export(path, procs, **kwargs)
#     148 "Export notebooks in `path` to Python modules"
#     149 if os.environ.get('IN_TEST',0): return
# --> 150 if not is_nbdev(): raise Exception('`nbdev_export` must be called from a directory within a nbdev project.')
#     151 if procs:
#     152     import nbdev.export
#
# Exception: `nbdev_export` must be called from a directory within a nbdev project.
