# %%
## This is the first tab for the log-in screen.

# %%
#| default_exp login

# %%
pip install ipywidgets ipyvuetify
# Out:
# Requirement already satisfied: ipywidgets in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (8.1.6)
# Collecting ipyvuetify
#   Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl (7.7 MB)
#      ---------------------------------------- 7.7/7.7 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: comm>=0.1.3 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipywidgets) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipywidgets) (3.0.14)
# Collecting ipyvue<2,>=1.7
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\asuphdaiproject\jupyter-mentor\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Installing collected packages: ipyvue, ipyvuetify
# Successfully installed ipyvue-1.11.2 ipyvuetify-1.11.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#| export
import ipywidgets as widgets
from ipywidgets import VBox, HTML, HBox, Label, Tab, Output, Button, Text
from IPython.display import display, clear_output
import ipyvuetify as v

# %%
#| export
class Login(VBox):
    
    def __init__(self):
        super().__init__()
        
        # Username input
        self.username_input = v.TextField(label='Username:', placeholder='Enter username')
        
        # Password input   
        self.key_input = v.TextField(label='API Key:', placeholder='Enter API key')
        
        # Login button
        self.login_button = Button(description='Login')

        #Header
        self.header = v.Container(children=[
            v.Html(
                tag='h1',
                attributes={'title': 'a title'},
                children=['Log In']
            )
        ])

        
        # Arrange widgets vertically
        self.children = [
            self.header,  # Heading
            self.username_input,       # Username label and input box
            self.key_input,       # Password label and input box
            HBox([self.login_button], layout={'justify_content': 'flex-end'}),  # Login button aligned to the right
        ]

# %%
main = Login()
main
# Out:
# Login(children=(Container(children=[Html(attributes={'title': 'a title'}, children=['Log In'], layout=None, ta…

# %%
#| hide
import nbdev; nbdev.nbdev_export()
# Out:
# C:\asuPhdAiProject\jupyter-mentor\venv\Lib\site-packages\nbdev\export.py:88: UserWarning: Notebook 'C:\asuPhdAiProject\jupyter-mentor\nbs\00_main.ipynb' uses `#|export` without `#|default_exp` cell.
# Note nbdev2 no longer supports nbdev1 syntax. Run `nbdev_migrate` to upgrade.
# See https://nbdev.fast.ai/getting_started.html for more information.
#   warn(f"Notebook '{nbname}' uses `#|export` without `#|default_exp` cell.\n"
